# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"iphones.csv")

# %%
data.head()
# Out:
#              Title      Color  Price  Rating  Offer
# 0  Apple iPhone 15      Black  66499     4.6   16.0
# 1  Apple iPhone 15       Blue  66499     4.6   16.0
# 2  Apple iPhone 15       Pink  66499     4.6   16.0
# 3  Apple iPhone 15      Green  66499     4.6   16.0
# 4  Apple iPhone 14  Starlight  56999     4.6   18.0

# %%
data.isnull()
# Out:
#      Title  Color  Price  Rating  Offer
# 0    False  False  False   False  False
# 1    False  False  False   False  False
# 2    False  False  False   False  False
# 3    False  False  False   False  False
# 4    False  False  False   False  False
# ..     ...    ...    ...     ...    ...
# 486  False  False  False   False  False
# 487  False  False  False   False  False
# 488  False  False  False   False  False
# 489  False  False  False   False  False
# 490  False  False  False   False  False
#
# [491 rows x 5 columns]

# %%
data.describe()
# Out:
#                Price      Rating       Offer
# count     491.000000  491.000000  491.000000
# mean    87973.183299    4.557026    5.558045
# std     43017.476047    0.127642    9.769705
# min      6199.000000    3.900000    0.000000
# 25%     51499.500000    4.500000    0.000000
# 50%     75999.000000    4.600000    0.000000
# 75%    123100.000000    4.600000    7.000000
# max    188900.000000    5.000000   60.000000

# %%
data.isnull().sum()
# Out:
# Title     0
# Color     0
# Price     0
# Rating    0
# Offer     0
# dtype: int64

# %%
# Group the data by color and calculate the average price for each color
avg_price_by_color = data.groupby('Color')['Price'].mean().sort_values(ascending=False)

# Plot the results
plt.figure(figsize=(10,6))
sns.barplot(x=avg_price_by_color.index, y=avg_price_by_color.values, palette='viridis')
plt.xticks(rotation=90)
plt.title('Average Price by Color')
plt.xlabel('Color')
plt.ylabel('Average Price')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22996\345832257.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_price_by_color.index, y=avg_price_by_color.values, palette='viridis')
